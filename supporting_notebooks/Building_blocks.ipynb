# %% [markdown]
# # Building Blocks of the Bell Multiport Interferometer

# %%
from multiport_interferometer import bell_components as c

# %% [markdown]
# ## Tunable Basic Unit - Symmetric Mach Zhender Interferometer

# %%
c.mzi().plot()

# %% [markdown]
# ## Phase Shifter

# %%
c.phaser().plot()

# %% [markdown]
# ## Input/Output Phase Shifter

# %%
c.edge_phase_shifter().plot()

# %% [markdown]
# ## Edge Waveguide

# %%
c.plain_wvgd().plot()

# %% [markdown]
# ## Input/Output Waveguide

# %%
c.edge_wvgd().plot()
